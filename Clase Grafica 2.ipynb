# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from sympy import *
init_printing()
# Out:
# /Users/AbrahamJC/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:232: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
x,y=var("x y")
x,y

f=x**3 - 3*x**2-24*x+32
df=f.diff()
ddf=df.diff()
df,ddf
# Out:
# ⎛   2                    ⎞
# ⎝3⋅x  - 6⋅x - 24, 6⋅x - 6⎠

# %%
pc=solve(df)
pc
# Out:
# [-2, 4]

# %%
plot(f)
# Out:
# <img src="data:image/png;base64,..." width="640">
